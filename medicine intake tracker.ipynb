# %%
while True:
    a = input('user name: ')
    b = input('password: ')
    #testcase username = Dave123
    #testcase password = password123
    if a == 'Dave123' and b == 'password123':
        print('Hello Dave\t\t\t\t\tWelcome to Medicine Intake Tracker')
        print("You’re doing the best you can, and that starts with taking your medicine.")
        
        print('Info\nGP: Dr satish\nUser: Dave\nCondition: Diabetic')
        medicine = ['Metformin','Sulfonylureas','DPP-4 Inhibitors','SGLT2 Inhibitors','Thiazolidinediones']
        medicine_intake = []
        intake_count = 0
        missed_medicine = []
        missed_count = 0
        #start with current date and time
        
        time_of_day = input('What time is it Dave? Morning, Afternoon, or Night')
        if time_of_day == 'Morning':
            print('Hello Dave, time to take Metformin, and Sulfonylureas.')
            a = input('Did you take your medication Dave? Y or N').upper()
            if a == 'Y':
                medicine_intake.extend(('Metformin','Sulfonylureas'))
                intake_count +=1
            else:
                missed_medicine.extend(('Metformin','Sulfonylureas'))
                missed_count+=1
        elif time_of_day == 'Afternoon':
            print('Hello Dave, time to take DPP-4 Inhibitors, and SGLT2 Inhibitors')
            a = input('Did you take your medication Dave? Y or N').upper()
            if a == 'Y':
                medicine_intake.extend(('DPP-4 Inhibitors','SGLT2 Inhibitors'))
                intake_count +=1
            else:
                missed_medicine.extend(('DPP-4 Inhibitors','SGLT2 Inhibitors'))
                missed_count+=1
        
        else:
            print('Hello Dave, time to take Metformin, and Thiazolidinediones')
            a = input('Did you take your medication Dave? Y or N').upper()
            if a == 'Y':
                medicine_intake.extend(('Metformin',  'Thiazolidinediones'))
                intake_count +=1
            else:
                missed_medicine.extend(('Metformin',  'Thiazolidinediones'))
                missed_count+=1
        
        
        
        print('============MENU===========\n\n')
        print('History\nMissed\nContact')
        print('What would you like to check? ')
        a = input()
        if a == 'History':
            print(medicine_intake)
            print(f'You took your medicine {intake_count} number of times correctly. Keep going')
        elif a == 'Missed':
            print(missed_medicine)
            print(f'You missed to take your medicine {missed_count} number of times. Dont give up Dave. Good days ahead')
        else:
            print('For emergency, contact your hospital at +***********')

        break
    else:
        print('Username or password is wrong\nPlease try again')
